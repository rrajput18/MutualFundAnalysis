# %% [markdown]
# # Day 1: Data Ingestion\nProfiles raw datasets and checks AMFI mappings.

# %%
import pandas as pd\nfrom pathlib import Path\nraw_dir = Path('../data/raw')\nfor f in raw_dir.glob('*.csv'):\n    df = pd.read_csv(f)\n    print(f'File: {f.name} | Shape: {df.shape}')
